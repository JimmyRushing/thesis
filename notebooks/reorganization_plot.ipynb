# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [100,200,300,400,500,600,700,800]
y = [1.86,.58, .26, .064, .026, .01, .003, .0015]
error = [.0095,.003, .001, .0004, .0001, .00007, .00002, .000012]
fig = plt.figure(figsize = (8, 6), dpi=300)

ax = plt.axes()
ax.set_xlabel('$\mathregular{\lambda}$ - Reorganization energy (meV)',fontdict=dict(weight='bold'),fontsize= 16,labelpad =14)
ax.set_ylabel('Mobility ($\mathregular{cm^{2}}$/ Vs)',fontdict=dict(weight='bold'), fontsize= 16,labelpad =12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax.set_yscale('log')
#plt.ylim([-.5, 2])
#plt.scatter(x,y,marker ='x',s = 400,lw=5, color = 'dodgerblue')
p = ax.plot(x, y,'o', color = 'dodgerblue',linestyle='--', linewidth=2, markersize = 15);
ax2= fig.add_subplot(222)
ax2.set_xlabel("Marcus Hopping", fontsize = 12)
ax2.set_xticks([])
ax2.set_yticks([])

ax2.spines["left"].set_visible(False)
ax2.spines["bottom"].set_visible(False)

ax2.annotate("", xytext=(1.5, 0.5), xy=(1.515, .05),
            arrowprops=dict(arrowstyle="<->",lw=2))
ax2.annotate("", xytext=(2.5, 0.05), xy=(1.5, .05),
            arrowprops=dict(arrowstyle="-",linestyle = '--'))
ax2.annotate("$\mathregular{\lambda}$",(1.25,0.3), fontsize = 15)
a = np.linspace(0,4,100)
b = .5*(a-2.5)**2+.05
plt.plot(a,b,scaley = False, color = "darkorange", linewidth = 3)
c = np.linspace(0,4,100)
d = .5*(a-1.5)**2+.1
plt.plot(c,d,scaley = False,color = "darkorange", linewidth = 3)

#line = np.linspace(100,800,1000)
#ax.plot(line, line*0, color = "black")

# %%
fig.savefig('../src/figures/reorg-log-yaxis', bbox_inches = "tight", facecolor = "white")

# %%
import numpy as n
np.mean(error)
# Out:
# 0.0017627500000000002

# %%
x = [400,500,600,700,800]
y = [ .064, .026, .01, .003, .0015]
error = [.0095,.003, .001, .0004, .0001, .00007, .00002, .000012]
fig = plt.figure(figsize = (10, 10))
ax = plt.axes()
ax.set_xlabel('Reorganization energy',fontdict=dict(weight='bold'))
ax.set_ylabel('Mobility',fontdict=dict(weight='bold'))

plt.scatter(x,y,marker ='o',s = 200)

;
# Out:
# ''

# %%
fig = plt.figure(figsize = (8, 6), dpi=300)

ax = plt.axes()

ax.set_xlabel("Nuclear Coordinates", fontsize = 16)

ax.set_ylabel("Potential Energy", fontsize = 16)

ax.annotate("", xytext=(1.5, 0.5), xy=(1.515, .05),
            arrowprops=dict(arrowstyle="<->",lw=2))

ax.annotate("", xytext=(2.5, 0.05), xy=(1.05, .05),
            arrowprops=dict(arrowstyle="-",linestyle = '--'))

ax.annotate("$\mathregular{\lambda_{ij}}$",(1.25,0.3), fontsize = 16)

ax.annotate("", xytext=(1.05, .1), xy=(1.515, .1),
            arrowprops=dict(arrowstyle="-",linestyle = '--'))

ax.annotate("", xytext=(1, .118), xy=(1, 0.035),
            arrowprops=dict(arrowstyle="<->",lw=2))

ax.annotate("$\mathregular{\Delta E_{ij}}$",(.6, .065), fontsize = 16)

ax.annotate("$\mathregular{C_{i}^*/C_{j}}$",(.38, .8), fontsize = 16)

ax.annotate("$\mathregular{C_{i}/C_{j}^*}$",(1.35, .8), fontsize = 16)

a = np.linspace(0,4,100)
b = .5*(a-2.5)**2+.05
plt.plot(a,b,scaley = False, color = "darkorange", linewidth = 4)
c = np.linspace(0,4,100)
d = .5*(a-1.5)**2+.1
plt.plot(c,d,scaley = False,color = "darkorange", linewidth = 4)

ax.set_xticks([])
ax.set_yticks([])


#line = np.linspace(100,800,1000)
#ax.plot(line, line*0, color = "black")
# Out:
# []

# %%
fig.savefig('../src/figures/marcus-plot', bbox_inches = "tight", facecolor = "white")

# %%
y = [.11,.01,.123]
y1 = [.0018,.00147,.2]
y2 = [.129,.158,.174]
x = ['Amorphous','Semi-crystalline', "Crystalline"]
error = [.0095,.003, .001, .0004, .0001, .00007, .00002, .000012]
fig = plt.figure(figsize = (8, 6), dpi=300)

ax = plt.axes()
ax.set_xlabel('',fontdict=dict(weight='bold'),fontsize= 16,labelpad =14)
ax.set_ylabel('Mobility ($\mathregular{cm^{2}}$/ Vs)',fontdict=dict(weight='bold'), fontsize= 16,labelpad =12)
plt.xticks(fontsize=14, weight = 'bold')
plt.yticks(fontsize=14)
ax.set_yscale('log')
#plt.ylim([-.5, 2])
#plt.scatter(x,y,marker ='x',s = 400,lw=5, color = 'dodgerblue')
ax.plot(x, y,'o', color = 'dodgerblue',linestyle='--', linewidth=2, markersize = 15);
ax.plot(x, y1,'o', color = 'darkorange',linestyle='--', linewidth=2, markersize = 15);
#polydisperse data  below
#ax.plot(x, y2,'o', color = 'black',linestyle='--', linewidth=2, markersize = 15);
plt.legend(['Miller 2018', 'This work'],loc="lower right", fontsize = 14)

# %%
fig.savefig('../src/figures/validation', bbox_inches = "tight", facecolor = "white")

# %%
x = np.load("/Users/jimmy/cmelab/data/itic-workspace/master_list.npy")

# %%
# Out:
# array([[     0,      9,      8, ...,    177,    174,    176],
#        [   186,    195,    194, ...,    363,    360,    362],
#        [   372,    381,    380, ...,    549,    546,    548],
#        ...,
#        [185442, 185451, 185450, ..., 185619, 185616, 185618],
#        [185628, 185637, 185636, ..., 185805, 185802, 185804],
#        [185814, 185823, 185822, ..., 185991, 185988, 185990]])

# %%
list =[]
for j in x:
    for i in j:
        
        string = "ParticleIndex!="+str(i)+"&&" 
        list.append(string)
s = ""
for item in list:
    s += item
s
# Out:
# 'ParticleIndex!=0&&ParticleIndex!=9&&ParticleIndex!=8&&ParticleIndex!=7&&ParticleIndex!=1&&ParticleIndex!=3&&ParticleIndex!=2&&ParticleIndex!=5&&ParticleIndex!=4&&ParticleIndex!=6&&ParticleIndex!=10&&ParticleIndex!=12&&ParticleIndex!=13&&ParticleIndex!=11&&ParticleIndex!=14&&ParticleIndex!=15&&ParticleIndex!=17&&ParticleIndex!=16&&ParticleIndex!=18&&ParticleIndex!=20&&ParticleIndex!=19&&ParticleIndex!=21&&ParticleIndex!=22&&ParticleIndex!=23&&ParticleIndex!=24&&ParticleIndex!=25&&ParticleIndex!=26&&ParticleIndex!=28&&ParticleIndex!=29&&ParticleIndex!=27&&ParticleIndex!=30&&ParticleIndex!=31&&ParticleIndex!=32&&ParticleIndex!=94&&ParticleIndex!=96&&ParticleIndex!=95&&ParticleIndex!=91&&ParticleIndex!=93&&ParticleIndex!=98&&ParticleIndex!=97&&ParticleIndex!=92&&ParticleIndex!=99&&ParticleIndex!=102&&ParticleIndex!=100&&ParticleIndex!=101&&ParticleIndex!=161&&ParticleIndex!=162&&ParticleIndex!=163&&ParticleIndex!=164&&ParticleIndex!=167&&ParticleIndex!=165&&ParticleIndex!=166&&ParticleI
# ...

# %%
y= x[0]
list =[]
for j in y:

        
    string = "ParticleIndex!="+str(j)+"&&" 
    list.append(string)
s = ""
for item in list:
    s += item
s
# Out:
# 'ParticleIndex!=0&&ParticleIndex!=9&&ParticleIndex!=8&&ParticleIndex!=7&&ParticleIndex!=1&&ParticleIndex!=3&&ParticleIndex!=2&&ParticleIndex!=5&&ParticleIndex!=4&&ParticleIndex!=6&&ParticleIndex!=10&&ParticleIndex!=12&&ParticleIndex!=13&&ParticleIndex!=11&&ParticleIndex!=14&&ParticleIndex!=15&&ParticleIndex!=17&&ParticleIndex!=16&&ParticleIndex!=18&&ParticleIndex!=20&&ParticleIndex!=19&&ParticleIndex!=21&&ParticleIndex!=22&&ParticleIndex!=23&&ParticleIndex!=24&&ParticleIndex!=25&&ParticleIndex!=26&&ParticleIndex!=28&&ParticleIndex!=29&&ParticleIndex!=27&&ParticleIndex!=30&&ParticleIndex!=31&&ParticleIndex!=32&&ParticleIndex!=94&&ParticleIndex!=96&&ParticleIndex!=95&&ParticleIndex!=91&&ParticleIndex!=93&&ParticleIndex!=98&&ParticleIndex!=97&&ParticleIndex!=92&&ParticleIndex!=99&&ParticleIndex!=102&&ParticleIndex!=100&&ParticleIndex!=101&&ParticleIndex!=161&&ParticleIndex!=162&&ParticleIndex!=163&&ParticleIndex!=164&&ParticleIndex!=167&&ParticleIndex!=165&&ParticleIndex!=166&&ParticleI
# ...

# %%
def plot_potential_energy(filename, start= 0):
    potential_energy = np.loadtxt(filename,skiprows=1, usecols=[4])
    plt.plot(np.arange(start=start,stop=start+len(potential_energy[start:])),potential_energy[start:])
    plt.ylabel('Potential Energy')
    plt.xlabel('timesteps')

# %%
logfile = "/Users/jimmy/repos/thesis/gsds/ITIC/trajectory.log"
plot_potential_energy(filename = logfile)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-50-10b8fc101c56> in <module>
#       1 logfile = "/Users/jimmy/repos/thesis/gsds/ITIC/trajectory.log"
# ----> 2 plot_potential_energy(filename = logfile)
#
# <ipython-input-49-57f0fe052696> in plot_potential_energy(filename, start)
#       1 def plot_potential_energy(filename, start= 0):
# ----> 2     potential_energy = np.loadtxt(filename,skiprows=1, usecols=[4])
#       3     plt.plot(np.arange(start=start,stop=start+len(potential_energy[start:])),potential_energy[start:])
#       4     plt.ylabel('Potential Energy')
#       5     plt.xlabel('timesteps')
#
# ~/miniconda3/envs/morphct-ex/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1089         # Skip the first `skiprows` lines
# ...
