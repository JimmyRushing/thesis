# %%
import matplotlib.pyplot as plt

# %%
x = [100,150,200,250,300,350,400,450,500,550,600,650,700,750,800]
y = [ .0021,.003,.019,.08,.17,.23,.37,.45,.49,.42,.48,.55,.61,.6,.55]

fig = plt.figure(figsize = (5, 5))

ax = plt.axes()
ax.set_xlabel('Temperature(K)',fontdict=dict(weight='bold'),fontsize= 16,labelpad =14)
ax.set_ylabel('Mobility ($\mathregular{cm^{2}}$/ Vs)',fontdict=dict(weight='bold'), fontsize= 16,labelpad =12)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.scatter(x,y,marker ='o',s = 100)
#p = ax.plot(x, y,'x', color = 'black',linestyle='--', linewidth=2, markersize = 15);
;
# Out:
# ''

# %%
fig.savefig('../src/figures/temp', bbox_inches = "tight", facecolor = "white")

# %%
x = [100,150,200,250,300,350,400,450,500,550,600,650,700,750,800]
y = [ 26,33,49,75,104,141,174,215,255,295,313,346,354,398,403]

fig = plt.figure(figsize = (5, 5))
ax = plt.axes()
ax.set_xlabel('Temperature(K)',fontdict=dict(weight='bold'),fontsize= 16,labelpad =14)
ax.set_ylabel('KMC wall time (min)',fontdict=dict(weight='bold'), fontsize= 16,labelpad =12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.scatter(x,y,marker ='o',s = 100)

;
# Out:
# ''

# %%
fig.savefig('../src/figures/temp_simtime_plot', bbox_inches = "tight", facecolor = "white")

# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.6150792673744948

# %%
#x = np.linspace(.5,1, 100)

y = np.log(1/x)

fig = plt.figure(figsize = (5, 5), dpi =300)
ax = plt.axes()
ax.set_xlabel('x',fontdict=dict(weight='bold'),fontsize= 16,labelpad =14)
ax.set_ylabel('ln(1/x)',fontdict=dict(weight='bold'), fontsize= 16,labelpad =12)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.plot(x,y, lw =4, color = "darkorange")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-103be5507823> in <module>
#       1 #x = np.linspace(.5,1, 100)
#       2 x = waittime_shift
# ----> 3 y = np.log(1/x)
#       4
#       5 fig = plt.figure(figsize = (5, 5), dpi =300)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'list'

# %%
fig.savefig('../src/figures/naturallog', bbox_inches = "tight", facecolor = "white")

# %%
x = [1e-13, 1e-12, 1e-11, 1e-10, 1e-9]

y = [ .17, .15, .14, .13, .136]

fig = plt.figure(figsize = (5, 5), dpi=300)

ax = plt.axes()
ax.set_xscale('log')
ax.set_xlabel('First Lifetime(s)',fontdict=dict(weight='bold'),fontsize= 16,labelpad =14)
ax.set_ylabel('Mobility ($\mathregular{cm^{2}}$/ Vs)',fontdict=dict(weight='bold'), fontsize= 16,labelpad =12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.scatter(x,y,marker ='o',s = 100)

;
# Out:
# ''

# %%
fig.savefig('../src/figures/lifetime', bbox_inches = "tight", facecolor = "white")

# %%
#Just playing with how many samples it takes to key an order of magntiude shift waitime
#we can do better and report the number of times a 
extended_waittimes = 0
shortened_waittimes = 0
for i in list(range(5000000)):
    x = np.random.random()
    if np.log(1/x) > 1000:
        extended_waittimes += 1
    if np.log(1/x) < 1e-4:
        shortened_waittimes += 1

# %%
extended_waittimes
# Out:
# 0

# %%
shortened_waittimes
# Out:
# 478

# %%
xs = []
waittime_shift = []
for i in list(range(100)):
    x = np.random.random()
    xs.append(x)
    waittime_shift.append(np.log(1/x))

# %%
#my plot wasnt sayin what I wanted to. bit something like the below could do it .s


x = xs

y = waittime_shift

fig = plt.figure(figsize = (5, 5), dpi =300)
ax = plt.axes()
ax.set_xlabel('x',fontdict=dict(weight='bold'),fontsize= 16,labelpad =14)
ax.set_ylabel('ln(1/x)',fontdict=dict(weight='bold'), fontsize= 16,labelpad =12)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)



plt.scatter(x, y,c=y, s=100)
